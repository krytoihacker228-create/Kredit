# %%
#сохранение модели
with open('anton_model.pkl', 'wb') as f:
  pickle.dump(model, f)

with open('anton_scaler.pkl', 'wb') as f:
  pickle.dump(scaler, f)

# %%
#загрузка модели
with open('anton_model.pkl', 'rb') as f:
  model = pickle.load(f)

with open('anton_scaler.pkl', 'rb') as f:
  scaler = pickle.load(f)
